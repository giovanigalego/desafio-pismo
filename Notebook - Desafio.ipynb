# %% [markdown]
# <h1>Case Pismo - Data Engineering</h1>

# %% [markdown]
# <h2>Desafio Proposto</h2>
# <body>Com os dados fornecidos, o desafio é construir uma solução que seja capaz de consumir o conjunto de arquivos e separá-los em diretórios para cada tipo de evento.</body>
# - Observações importantes:
#   - Usar python
#   - Os diretórios devem ser particionados em: ano, mês, dia
#   - O arquivo final deve estar em parquet
#   - Deve ser mantido sempre o arquivo mais atual, em caso de duplicidade

# %%
import pyspark.sql.functions as sf

df_to_json = sqlContext\
    .read\
    .json(sc
          .wholeTextFiles("s3://desafio-pismo/*.json")
          .values()
          .flatMap(lambda x: x
                   .replace("\n", "#!#")
                   .replace("{#!#", "{")
                   .replace("#!#}", "}")
                   .replace(",#!#", ",")
                   .replace("}{", "},{")
                   .replace("},{", "},#####")
                   .replace('{"timestamp"','[{"timestamp"')
                   .replace("},#####","#####,#####")
                   .replace("}}}","}}}]")
                   .replace("#####,#####","},{")
                   .split("#!#")
                  )
         )\

display(df_to_json)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>data</th><th>domain</th><th>event_id</th><th>event_type</th><th>timestamp</th></tr></thead><tbody><tr><td>List(null, 13.0, null, null, null, 186295, null, null, null, null, List(UNBLGBYV, 5551969893626), null, CELPHONE_RECHARGE)</td><td>transaction</td><td>6d7d0c85-94a2-4bf0-a570-72774e4fbc0d</td><td>creation</td><td>2021-01-01T00:00:29</td></tr><tr><td>List(null, null, null, null, null, 40093, ACTIVE, SUSPENDED, null, Quas., null, null, null)</td><td>account</td><td>96579a99-7deb-4691-95d3-390178936615</td><td>status-change</td><td>2021-01-01T00:00:51</td></tr><tr><td>List(null, 4.0, null, null, null, 384341, null, null, null, null, List(HBVVGBE5, 5521944543480), null, CELPHONE_RECHARGE)</td><td>transaction</td><td>bfa28493-b97c-4ee6-9612-f6422d185229</td><td>creation</td><td>2021-01-01T00:01:01</td></tr><tr><td>List(null, null, null, null, null, 553807, ACTIVE, SUSPENDED, null, Quidem quidem facilis nostrum pariatur., null, null, null)</td><td>account</td><td>7b2480cc-50ed-4a57-8bd2-ace0d78da198</td><td>status-change</td><td>2021-01-01T00:01:37</td></tr><tr><td>List(null, 92.0, null, null, null, 170156, null, null, null, null, List(UTRIGBZE, 5581980129475), null, CELPHONE_RECHARGE)</td><td>transaction</td><td>abd543ca-ace2-490e-8757-214c69da76ab</td><td>creation</td><td>2021-01-01T00:04:14</td></tr><tr><td>List(null, 92.0, null, null, null, 170156, null, null, null, null, List(UTRIGBZE, 5581980129475), null, CELPHONE_RECHARGE)</td><td>transaction</td><td>abd543ca-ace2-490e-8757-214c69da76ab</td><td>creation</td><td>2021-01-01 00:04:15</td></tr><tr><td>List(null, 9288.81, null, null, List(9971, Minus mollitia., Mirella da Costa), 748292, null, null, null, null, null, null, CASHIN)</td><td>transaction</td><td>5d743c5e-a967-4118-b4f6-e9963affb3fe</td><td>creation</td><td>2021-01-01T00:05:43</td></tr><tr><td>List(null, null, null, null, null, 976984, JUDICIAL_BLOCK, ACTIVE, null, Dicta vero., null, null, null)</td><td>account</td><td>63987632-f9f9-4de6-8256-0b
null, null, List(1953-12-19, Beatriz Viana, Tecelão), null, null, null, null)</td><td>account</td><td>b35644e1-4e4d-4987-899b-0dacf7c9fb49</td><td>creation</td><td>2021-01-01 00:19:39</td></tr><tr><td>List(null, null, null, null, null, 660568, SUSPENDED, ACTIVE, null, Eum doloremque., null, null, null)</td><td>account</td><td>ff903c11-42ee-4dc8-9788-1d93442fe273</td><td>status-change</td><td>2021-01-01T00:20:32</td></tr><tr><td>List(null, 9700.21, null, null, null, 674166, null, null, null, null, null, List(2181, Repudiandae., Henrique Viana), CASHOUT)</td><td>transaction</td><td>908c8891-60de-4d29-adeb-9b607bba315c</td><td>creation</td><td>2021-01-01T00:20:56</td></tr><tr><td>List(null, 9700.21, null, null, null, 674166, null, nul

# %% [markdown]
# <h2>Transform</h2>
# - Nesse bloco estamos fazendo a `leitura` e `validação` da estrutura json dos arquivos e aplicando a correção via `replace`

# %% [markdown]
# <h3>Dando continuidade ao tratamento dos dados:</h3>
# - No primeiro passo foi feito o tratamento do campo `timestamp` por alguns registros virem com o `T` e outros não, assim foi normalizado
# - Após isso a mesma tipo de dados da coluna foi convertido de `string` para `timestamp`, para ser feito o tratamento usando um campo de data
# - Concatenando os campos, obtivemos os tipos de eventos
# - Logo após foi extraído o ano e mês dos registros
# - Em seguida está sendo retornado o ultimo event_id de cada registro tendo como base a coluna `timestamp`
# - Por fim, foi feita a separação das partições necessários da data, que são: `ano`, `mês` e `dia`

# %%
eventsDF = (df_to_json.withColumn("timestamp", sf.regexp_replace("timestamp", "T", " "))
            .withColumn("timestamp", sf.to_timestamp(sf.col("timestamp"), "yyyy-MM-dd HH:mm:ss"))
            .withColumn("event_key", sf.concat(sf.col("domain"),sf.lit('_'), sf.col("event_type")))
            .groupBy("event_id", "domain", "event_type", "event_key", "data").agg(sf.max("timestamp").alias("timestamp"))
            .withColumn("date", sf.split(sf.to_date(sf.col("timestamp")),"-"))
            .withColumn("year", sf.col("date").getItem(0))
            .withColumn("month", sf.col("date").getItem(1))
            .withColumn("day", sf.col("date").getItem(2))
            .select("timestamp", "event_id", "domain", "event_type", "event_key", "year","month","day", "data")
        )

display(eventsDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>timestamp</th><th>event_id</th><th>domain</th><th>event_type</th><th>event_key</th><th>year</th><th>month</th><th>day</th><th>data</th></tr></thead><tbody><tr><td>2021-01-01T01:14:40.000+0000</td><td>a8a42041-27d0-4332-b716-4948dbdcdcf9</td><td>transaction</td><td>creation</td><td>transaction_creation</td><td>2021</td><td>01</td><td>01</td><td>List(null, 9588.73, null, null, List(1805, Dignissimos quaerat esse perferendis., Mariana Aragão), 556775, null, null, null, null, null, null, CASHIN)</td></tr><tr><td>2021-01-01T08:05:30.000+0000</td><td>c0aee4d8-2948-4d49-9123-3101d16678c4</td><td>transaction</td><td>creation</td><td>transaction_creation</td><td>2021</td><td>01</td><td>01</td><td>List(null, 8764.7, null, null, List(9973, Laboriosam voluptatem., Vitória Araújo), 920085, null, null, null, null, null, null, CASHIN)</td></tr><tr><td>2021-01-01T14:38:48.000+0000</td><td>8c9654b9-1188-4ad2-9ae1-f6847b177c4a</td><td>account</td><td>status-change</td><td>account_status-change</td><td>2021</td><td>01</td><td>01</td><td>List(null, null, null, null, null, 398434, ACTIVE, SUSPENDED, null, Natus odit nemo aliquam dicta laudantium doloribus impedit., null, null, null)</td></tr><tr><td>2021-01-01T20:41:34.000+0000</td><td>c30eb3e8-381e-4fa2-b710-eb17ee1a8249</td><td>transaction</td><td>creation</td><td>transaction_creation</td><td>2021</td><td>01</td><td
td>account_creation</td><td>2021</td><td>01</td><td>02</td><td>List(null, null, List(List(List(Freitas de Moreira, Jardim Atlântico, 708, 15121748, Pará, PI, Morro de Peixoto, Street), List(Sales, Piratininga, 915, 39552169, Rio Grande do Sul, MS, Ladeira Ana Laura Costela, Street), List(Martins Paulista, Serra, 95, 17828-049, Distrito Federal, PI, Distrito Pinto, Street)), Mendes), null, null, 746100, null, null, List(1945-02-01, Lara Cunha, Escrivão), null, null, null, null)</td></tr><tr><td>2021-01-02T13:22:28.000+0000</td><td>09e1460e-3c4c-4171-aa1a-c302242b90a6</td><td>account</td><td>creation</td><td>account_creation</td><td>2021</td><td>01</td><td>02</td><td>List(List(), null, List(List(List(Ferreira, Céu Azul, 503, 35964-715, Rondônia, AP, Viela Larissa Mendes, Street), List(Araújo, São Vicente, 75, 89379751, Rondônia, RR, Morro das Neves, Street), List(Santos de Peixoto, Olaria, 18, 23377610, Paraíba, PR, Jardim de da Conceição, Street)), Peixoto), null, null, 648186, null, null, List(1982-03-04, Letícia Cunha, Trilheiro ou músico de cinema), null, null, null, null)</td></tr><tr><td>2021-01-02T15:12:46.000+0000</td><td>933d9343-b8da-4e30-8b7a-b2c0ca3675ec</td><td>account</td><td>creation</td><td>account_creation</td><td>2021</td><td>01</td><td>02</td><td>List(null, null, null, null, null, 990195, null, null, List(1959-03-17, Kevin da Conceição, Levantador de peso), null, null, null, null)</td></tr><tr><td>2021-01-02T20:56:52.000+0000</td><td>f916c114-013d-4475-b6dd-719dce3676c4</td><td>transaction</td><td>creation</td><td>transaction_creation</td><td>2021</td><td>01</td><td>02</td><td>List(null, 9897.37, null, null, null, 603405, null, null, null, null, null, List(9869, Tempora recusandae dignissimos ratione sapiente., Dr. Ian da Costa), CASHOUT)</td></tr><tr><td>2021-01-02T21:33:54.000+0000</td><td>f550647f-a1d4-4d1b-8471-4b3f72b0889c</td><td>transaction</td><td>creation</td><td>transaction_creation</td><td>2021</td><td>01</td><td>02</td><td>List(null, 45.0, null, null, null, 633460, null, null, null, null, List(EEUEGBV3, 5511982933277), null, CELPHONE_RECHARGE)</td></tr><tr><td>2021-01-02T21:50:12.000+0000</td><td>3b6e67ee-118d-4705-8c84-79d50c7a3f22</td><td>transaction</td><td>creation</td><td>transaction_creation</td><td>2021</td><td>01</td><td>02</td><td>List(null, 7532.2, null, null, null, 915710, null, null, null, null, null, List(6033, Aliquid necessitatibus aliquam., Dr. Pedro Miguel Viana), CASHOUT)</td></tr><tr><td>2021-01-02T22:27:41.000+0000</td><td>bf7dafca-6539-41a4-b271-7db1ae7ad90f</td><td>transaction</td><td>creation</td><td>transaction_creation</td><td>2021</td><td>01</td><td>02</td><td>Lis

# %% [markdown]
# <h2>Load</h2>
# - No bloco final estamos escrevendo os arquivos em formato `parquet` e em diretórios particionados por: `event_key`, `year`, `month`, `day`

# %%
eventsDF.write.mode("overwrite").partitionBy("event_key", "year", "month", "day").parquet("s3://trusted-data-pismo/results")

# %% [markdown]
# <h3>Resultado</h3>
# Como podemos ver abaixo, o DataFrame final em parquet

# %%
df_parquet = spark.read.parquet("s3://trusted-data-pismo/results")
display(df_parquet)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>timestamp</th><th>event_id</th><th>domain</th><th>event_type</th><th>data</th><th>event_key</th><th>year</th><th>month</th><th>day</th></tr></thead><tbody><tr><td>2021-02-01T12:43:07.000+0000</td><td>4c5687c4-e873-482d-808e-d7217c761127</td><td>transaction</td><td>creation</td><td>List(null, 9436.2, null, null, List(8697, Dolorem nam., Eloah Porto), 300820, null, null, null, null, null, null, CASHIN)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T16:16:33.000+0000</td><td>8721294c-6e72-47c9-ab73-54d2af887add</td><td>transaction</td><td>creation</td><td>List(null, 6469.95, null, null, null, 574498, null, null, null, null, null, List(4259, Reiciendis assumenda qui culpa vitae deserunt., Davi Luiz Duarte), CASHOUT)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T07:46:25.000+0000</td><td>f4cbfacc-dd4f-401d-9c5b-735ade5d76cd</td><td>transaction</td><td>creation</td><td>List(null, 8430.44, null, List(Residencial Evelyn Moura, 94
# Vila Independencia 1ª Seção
# 19803160 Almeida / RJ, List(47.92526, -97.03285, Grand Forks, US, America/Chicago), Mendes), null, 640069, null, null, null, null, null, null, DEBIT)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T07:54:02.000+0000</td><td>1848e803-f4c7-4b39-93af-b4fdf56f4c97</td><td>transaction</td><td>creation</td><td>List(null, 1921.62, null, null, null, 13986, null, null, null, null, null, List(4967, Occaecati illo., Amanda Farias), CASHOUT)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T13:52:10.000+0000</td><td>c17890fd-15ee-4a0c-b6f1-33fc5dd21c1b</td><td>transaction</td><td>creation</td><td>List(null, 8228.47, null, null, List(2859, Earum., Larissa Novaes), 503025, null, null, null, null, null, null, CASHIN)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T15:11:12.000+0000</td><td>024a2957-d4b7-47aa-8d8e-4e0c1f5e63d1</td><td>transaction</td><td>creation</td><td>List(null, 3852.32, null, List(Estrada de Araújo, 948
# Vila Satélite
# 21982454 Santos / RJ, List(46.32374, -120.00865, Sunnyside, US, America/Los_Angeles), Costela da Mota e Filhos), null, 696144, null, null, null, null, null, null, DEBIT)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T17:04:50.000+0000</td><td>28aa181b-8bc5-4d8f-aef6-db91bfd6e0f1</td><td>transaction</td><td>creation</td><td>List(null, 19.0, null, null, null, 609237, null, null, null, null, List(ZUQNGBRX, 5571957702694), null, CELPHONE_RECHARGE)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T22:02:57.000+0000</td><td>f880a0f6-10dd-4b12-9906-1512ff76b649</td><td>transaction</td><td>creation</td><td>List(null, 9740.72, null, null, List(6710, Iusto sint., Emilly Nunes), 948287, null, null, null, null, null, null, CASHIN)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T01:39:25.000+0000</td><td>f2822352-7463-44ea-89b8-a7c69875b29c</td><td>transaction</td><td>creation</td><td>List(null, 9869.23, null, null, List(6735, Iste expedita porro., Nina Fogaça), 875776, null, null, null, null, null, null, CASHIN)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T09:36:53.000+0000</td><td>85399c0a-bc88-45bf-912d-c3b8cd4a414a</td><td>transaction</td><td>creation</td><td>List(null, 7635.96, null, null, List(8014, Illum occaecati molestias aliquam optio., Srta. Gabrielly Moraes), 144261, null, null, null, null, null, null, CASHIN)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T12:09:43.000+0000</td><td>50e6f3d2-e99d-4037-9c7c-bffd1c2e1347</td><td>transaction</td><td>creation</td><td>List(null, 7.0, null, null, null, 226032, null, null, null, null, List(WRPCGB68, 5571910179440), null, CELPHONE_RECHARGE)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T15:09:31.000+0000</td><td>11e7af5f-b5bb-4702-9242-64cb90680651</td><td>transaction</td><td>creation</td><td>List(null, 7057.55, null, List(Distrito de da Conceição, 3
# Penha
# 97168-411 da Rosa de Jesus / AC, List(40.68066, -73.47429, Massapequa, US, America/New_York), Carvalho), null, 850251, null, null, null, null, null, null, DEBIT)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T23:35:33.000+0000</td><td>4eec6edf-e6ec-49a0-9c1b-f3652cc6afd0</td><td>transaction</td><td>creation</td><td>List(null, 8936.94, null, null, List(2708, Deleniti accusamus ab rem., Caroline da Cruz), 896964, null, null, null, null, null, null, CASHIN)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T02:38:02.000+0000</td><td>84d95f62-916a-42d0-bfaf-2fbfddbd4854</td><td>transaction</td><td>creation</td><td>List(null, 8877.5, null, null, List(9183, Reprehenderit voluptates possimus pariatur illo., Sra. Maria Alice Rocha), 913720, null, null, null, null, null, null, CASHIN)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T10:02:22.000+0000</td><td>bd5cb030-15c4-4af8-8f22-bfae9d0a056b</td><td>transaction</td><td>creation</td><td>List(null, 9927.33, null, null, List(1942, At suscipit aliquid., Isabelly Correia), 303309, null, null, null, null, null, null, CASHIN)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T10:32:20.000+0000</td><td>bc280a1d-8cf3-41e4-aa3b-1dcbef69a444</td><td>transaction</td><td>creation</td><td>List(null, 7808.48, null, null, List(1990, Sunt est., Melissa Gomes), 958795, null, null, null, null, null, null, CASHIN)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T11:57:52.000+0000</td><td>d9c56fe2-7a40-4db2-ba60-7fb403bb27c3</td><td>transaction</td><td>creation</td><td>List(null, 9509.52, null, null, List(5093, Nihil eligendi., Dra. Fernanda Vieira), 92977, null, null, null, null, null, null, CASHIN)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T23:20:52.000+0000</td><td>8d5f366a-d369-4d66-ae38-925bdefcb33b</td><td>transaction</td><td>creation</td><td>List(null, 25.0, null, null, null, 988901, null, null, null, null, List(USDZGBQF, 5541937513722), null, CELPHONE_RECHARGE)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T09:18:00.000+0000</td><td>ca7f30aa-aac0-478c-be45-da8ea3fc36b1</td><td>transaction</td><td>creation</td><td>List(null, 9820.0, null, null, List(9649, Excepturi expedita fugit., Caroline Santos), 49704, null, null, null, null, null, null, CASHIN)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T14:01:02.000+0000</td><td>354ddb3d-9bef-44c4-832f-72519b75f14c</td><td>transaction</td><td>creation</td><td>List(null, 9764.68, null, List(Chácara Heitor Gonçalves, 106
# Jaqueline
# 51200093 Aragão de Freitas / AP, List(38.17492, -122.2608, American Canyon, US, America/Los_Angeles), Pereira Melo e Filhos), null, 506848, null, null, null, null, null, null, DEBIT)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T15:50:45.000+0000</td><td>03775eb4-b5d0-4951-bf0f-410ff8739622</td><td>transaction</td><td>creation</td><td>List(null, 6858.66, null, null, List(5043, Id impedit odio., Davi Costela), 966270, null, null, null, null, null, null, CASHIN)</td><td>transaction_creation</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>2021-02-01T22:42:48.000+0000</td><td>b929afbf-732c-4b73-b240-ad6a394e26bd</td><

# %% [markdown]
# <h2>Explicação</h2>
#
# Para a resolução do desafio foi usado o Databricks para seu consumo, limpeza e carregamento dos dados, como armazenamento foi usado Amazon S3 Bucket. Inicialmente para a tratativa dos arquivos `JSON` foi usado uma lógica simples de `replace` tendo em vista que os arquivos não estavam com a estrutura padrão de um `JSON`, como por exemplo, os separadores de objetos não possuírem vírgula e os arquivos não começarem e não terminarem com `[]`. Para a validação dos registros duplicados foi aplicado um agrupamento com `MAX()` para buscar sempre o último registro e consequetemente excluindo os duplicado e por fim está sendo carregado no S3 particionado por `event_key` (campo criado com base na regra do contrato) e pelos campos `ano. mes e dia`.
